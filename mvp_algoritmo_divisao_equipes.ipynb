# %% [markdown]
# <a href="https://colab.research.google.com/github/ImpulsoGov/mensageria-mvp/blob/main/mvp_algoritmo_divisao_equipes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Configuração para divisão dos grupos de teste e controle dos municípios**

# %% [markdown]
# ##### Configurações iniciais do ambiente

# %%
# autenticação
from google.colab import auth
auth.authenticate_user()

# %%
# conexão BQ
from google.cloud import bigquery
client = bigquery.Client(project='predictive-keep-314223')

# %%
# importação de bibliotecas
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from google.oauth2 import service_account

# %% [markdown]
# ##### Consulta aos dados

# %%
query = """
    SELECT *
    FROM `predictive-keep-314223.ip_mensageria_camada_prata.unificado_lista_com_telefones_grupos_atendimentos`
"""

query_job = client.query(query)
df = query_job.to_dataframe()

# %% [markdown]
# ##### Preparação dos dados

# %%
# exclusão de cidadãos com registro de falecimento
df = df[df['se_faleceu']==0]

# %%
# identificação dos cidadãos com pendências em cada linha de cuidado
df['citopatologico_pendente'] = df['status_exame'].apply(lambda x: True if x in ('exame_nunca_realizado','exame_vencido','exame_vence_no_quadrimestre_atual') else False)
# Out:
# <ipython-input-78-b78de1522804>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['citopatologico_pendente'] = df['status_exame'].apply(lambda x: True if x in ('exame_nunca_realizado','exame_vencido','exame_vence_no_quadrimestre_atual') else False)

# %%
# função para identificar hipertensos em pendência
def pendencia_hipertensos(x):
    if x['esta_na_lista_hipertensos'] == True and (x['realizou_afericao_ultimos_6_meses'] == False or x['realizou_consulta_hip_ultimos_6_meses'] == False):
        return True
    else:
        return False

df['hipertensao_pendente'] = df.apply(pendencia_hipertensos,axis=1)

# %%
# função para identificar diabeticos em pendência
def pendencia_diabeticos(x):
    if x['esta_na_lista_diabeticos'] == True and (x['realizou_consulta_dia_ultimos_6_meses'] == False or x['realizou_solicitacao_hemoglobina_ultimos_6_meses'] == False):
        return True
    else:
        return False

df['diabetes_pendente'] = df.apply(pendencia_diabeticos,axis=1)

# %%
#calcular preenchimento de telefones
def calcula_percentual(df,telefone,esta_na_lista_citopatologico,esta_na_lista_hipertensos,esta_na_lista_diabeticos,municipio,equipe_ine,equipe_nome,):
    df_validos = df[df[telefone].notna() & (df[telefone] != '')]
    agrupado = df_validos.groupby([municipio,equipe_ine,equipe_nome,esta_na_lista_citopatologico,esta_na_lista_hipertensos,esta_na_lista_diabeticos])[telefone].nunique().reset_index(name='Telefones únicos')
    total_cuidado = df.groupby([municipio,equipe_ine,equipe_nome,esta_na_lista_citopatologico,esta_na_lista_hipertensos,esta_na_lista_diabeticos]).size().reset_index(name='Total cidadãos')
    resultado=pd.merge(agrupado, total_cuidado, on=[municipio,equipe_ine,equipe_nome,esta_na_lista_citopatologico,esta_na_lista_hipertensos,esta_na_lista_diabeticos], how='right')
    resultado['Percentual preenchido'] = (resultado['Telefones únicos']/resultado['Total cidadãos'])*100

    resultado['Telefones únicos'].fillna(0,inplace=True)
    resultado['Percentual preenchido'].fillna(0,inplace=True)

    return resultado

resultado=calcula_percentual(df,'celular_tratado','esta_na_lista_citopatologico','esta_na_lista_hipertensos','esta_na_lista_diabeticos','municipio','equipe_ine','equipe_nome')
resultado
# Out:
# <ipython-input-81-fc300ab3454a>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   resultado['Telefones únicos'].fillna(0,inplace=True)
# <ipython-input-81-fc300ab3454a>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   resultado['Percentual preenchido'].fillna(0,inplace=True)
#            municipio  equipe_ine            equipe_nome  \
# 0          Alagoinha  0000134945  PSF 03 - FREI ESTEVAO
# 1          Alagoinha  0000134945  PSF 03 - FREI ESTEVAO
# 2          Alagoinha  0000134945  PSF 03 - FREI ESTEVAO
# 3          Alagoinha  0000134945  PSF 03 - FREI ESTEVAO
# 4          Alagoinha  0000134945  PSF 03 - FREI ESTEVAO
# ..               ...         ...                    ...
# 761  Vitorino Freire  0002231484    ESF OZEAS CASTRO II
# 762  Vitorino Freire  0002231484    ESF OZEAS CASTRO II
# 763  Vitorino Freire  0002231484    ESF OZEAS CASTRO II
# 764  Vitorino Freire  0002231484    ESF OZEAS CASTRO II
# 765  Vitorino Freire  0002231484    ESF OZEAS CASTRO II
#
#      esta_na_lista_citopatologico  esta_na_lista_hipertensos  \
# 0                           False                      False
# 1                           False                       True
# 2                           False                       True
# 3                            True                      False
# 4                            True                      False
# ..                            ...                        ...
# 761                         False                       True
# 762                          True                      False
# 763                          True                      False
# 764                          True                       True
# 765                          True                       True
#
#      esta_na_lista_diabeticos  Telefones únicos  Total cidadãos  \
# 0                        True                 3               4
# 1                       False                40              52
# 2                        True                23              35
# 3                       False                43              53
# 4                        True                 3               5
# ..                        ...               ...             ...
# 761                      True                13              24
# 762                     False                29              46
# 763                      True                 1               1
# 764                     False                10              18
# 765                      True                 6              10
#
#      Percentual preenchido
# 0                75.000000
# 1                76.923077
# 2                65.714286
# 3                81.132075
# 4                60.000000
# ..                     ...
# 761              54.166667
# 762              63.043478
# 763             100.000000
# 764              55.555556
# 765              60.000000
#
# [766 rows x 9 columns]

# %%
from google.colab import drive
drive.mount ('/drive')
resultado.to_csv('/drive/MyDrive/preenchimento_telefones.csv', index=False)
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
#seleção de cidadãos com pendências
df_aptos_mensagens = df[(df['diabetes_pendente'] == True) | (df['hipertensao_pendente'] == True) | (df['citopatologico_pendente'] == True)]

# %% [markdown]
# #### Priorização das linhas de cuidado

# %%
# função para identificar cronicos em pendência
def pendencia_cronicos(x):
    if x['hipertensao_pendente'] or x['diabetes_pendente']:
        return True
    else:
        return False

df_aptos_mensagens['cronicos_pendente'] = df_aptos_mensagens.apply(pendencia_cronicos,axis=1)
# Out:
# <ipython-input-84-e13c521f5830>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aptos_mensagens['cronicos_pendente'] = df_aptos_mensagens.apply(pendencia_cronicos,axis=1)

# %%
# função para priorização da linha de cuidado -- caso seja parte de duas linhas de cuidado dividir aleatoriamente e igualmente entre crônicos ou cito

def linha_cuidado(x, y):
    if x and not y:
        return 'citopatologico'
    elif y and not x:
        return 'cronicos'
    else:
        return np.nan

df_aptos_mensagens['linha_cuidado'] = df_aptos_mensagens.apply(lambda row: linha_cuidado(row['citopatologico_pendente'], row['cronicos_pendente']), axis=1)

interseccao = df_aptos_mensagens['linha_cuidado'].isna()
total = interseccao.sum()

atribuicao = ['citopatologico'] * (total // 2) + ['cronicos'] * (total - total // 2)
np.random.shuffle(atribuicao)

df_aptos_mensagens.loc[interseccao, 'linha_cuidado'] = atribuicao
# Out:
# <ipython-input-85-b77bb472daa3>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aptos_mensagens['linha_cuidado'] = df_aptos_mensagens.apply(lambda row: linha_cuidado(row['citopatologico_pendente'], row['cronicos_pendente']), axis=1)

# %%
df_aptos_mensagens
# Out:
#                municipio                    nome_do_paciente  celular_tratado  \
# 4         Marajá do Sena                       RAIMUNDO DIAS       9982755267
# 9         Marajá do Sena                  VALMIR GOMES SILVA       9985006707
# 11        Marajá do Sena             GARDENIA SILVA LOURENCO                0
# 18        Marajá do Sena  IRANEIDE SANTOS DA SILVA CONCEICAO       9898476793
# 24        Marajá do Sena        JORDAO ALEXANDRE DE OLIVEIRA      98985051891
# ...                  ...                                 ...              ...
# 147567  Monsenhor Tabosa           ZILMAR PEREIRA DOS SANTOS       8836962175
# 147571  Monsenhor Tabosa          ZULEIDE FERREIRA DE BARROS       8836962170
# 147572  Monsenhor Tabosa                ZULEIDE SOUZA DA LUZ       8894038721
# 147573  Monsenhor Tabosa                ZULEIDE SOUZA DA LUZ       8894038721
# 147579  Monsenhor Tabosa             ZULENE MARTINS DE SOUZA       8898042817
#
#                     cns          cpf data_de_nascimento  \
# 4                  <NA>  94979200320         1975-04-03
# 9       898003404845244  94599670359         1954-10-15
# 11                 <NA>  61125298316         1996-02-12
# 18                 <NA>  97693502300         1977-05-30
# 24                 <NA>  98706403387         1956-02-28
# ...                 ...          ...                ...
# 147567             <NA>  83122656353         1976-01-28
# 147571  702402537247520  89691610310         1977-11-11
# 147572  705001080632757  97348546315         1972-12-01
# 147573  705001080632757  97348546315         1972-12-01
# 147579  165700955960007  47795026320         1967-05-10
#
#                ds_dim_situacao_trabalho ds_identidade_genero  \
# 4                                 Outro        Não informado
# 9              Aposentado / Pensionista        Não informado
# 11                        Não informado        Não informado
# 18                        Não informado        Não informado
# 24                        Não informado        Não informado
# ...                                 ...                  ...
# 147567  Autônomo sem previdência social        Não informado
# 147571                    Não informado        Não informado
# 147572                     Desempregado        Não informado
# 147573                            Outro        Não informado
# 147579                    Não informado        Não informado
#
#        no_social_cidadao  numero_visitas_ubs_ultimos_12_meses  ...  \
# 4                   None                                    0  ...
# 9                   None                                    0  ...
# 11                  None                                    0  ...
# 18                  None                                    0  ...
# 24                  None                                    1  ...
# ...                  ...                                  ...  ...
# 147567              None                                    0  ...
# 147571              None                                    0  ...
# 147572              None                                    4  ...
# 147573              None                                    4  ...
# 147579              None                                    0  ...
#
#         possui_diabetes_autorreferida  possui_diabetes_diagnosticada  \
# 4                               False                          False
# 9                               False                          False
# 11                              False                          False
# 18                              False                          False
# 24                              False                          False
# ...                               ...                            ...
# 147567                          False                          False
# 147571                          False                          False
# 147572                          False                          False
# 147573                          False                          False
# 147579                          False                          False
#
#         realizou_consulta_dia_ultimos_6_meses  \
# 4                                       False
# 9                                       False
# 11                                      False
# 18                                      False
# 24                                      False
# ...                                       ...
# 147567                                  False
# 147571                                  False
# 147572                                  False
# 147573                                  False
# 147579                                  False
#
#         realizou_solicitacao_hemoglobina_ultimos_6_meses mensagem_data_envio  \
# 4                                                  False
# 9                                                  False
# 11                                                 False
# 18                                                 False
# 24                                                 False
# ...                                                  ...                 ...
# 147567                                             False
# 147571                                             False
# 147572                                             False
# 147573                                             False
# 147579                                             False
#
#        citopatologico_pendente hipertensao_pendente  diabetes_pendente  \
# 4                        False                 True              False
# 9                        False                 True              False
# 11                        True                False              False
# 18                        True                False              False
# 24                       False                 True              False
# ...                        ...                  ...                ...
# 147567                    True                False              False
# 147571                    True                False              False
# 147572                    True                 True              False
# 147573                    True                 True              False
# 147579                    True                False              False
#
#        cronicos_pendente   linha_cuidado
# 4                   True        cronicos
# 9                   True        cronicos
# 11                 False  citopatologico
# 18                 False  citopatologico
# 24                  True        cronicos
# ...                  ...             ...
# 147567             False  citopatologico
# 147571             False  citopatologico
# 147572              True        cronicos
# 147573              True  citopatologico
# 147579             False  citopatologico
#
# [23271 rows x 38 columns]

# %%
df_equipes = pd.DataFrame(df_aptos_mensagens.pivot_table(index=['municipio','equipe_ine','equipe_nome'], columns='linha_cuidado', values='nome_do_paciente',aggfunc='count', fill_value=0))
df_equipes.reset_index(inplace=True)
# exclusão de registros sem equipe atribuída
df_equipes = df_equipes[df_equipes['equipe_ine']!='0']
df_equipes
# Out:
# linha_cuidado        municipio  equipe_ine                     equipe_nome  \
# 0                    Alagoinha  0000134945           PSF 03 - FREI ESTEVAO
# 1                    Alagoinha  0000134953  USF 04 DR ORISVALDO I DA SILVA
# 2                    Alagoinha  0000134961                          PSF 02
# 3                    Alagoinha  0000134988  PSF 01 MANOEL BEZERRA DA SILVA
# 4                    Alagoinha  0000134996            PSF 05 - BOM SUCESSO
# ..                         ...         ...                             ...
# 114            Vitorino Freire  0000064343            ESF BREJO DAS FLORES
# 115            Vitorino Freire  0000064351                  ESF RENASCENCA
# 116            Vitorino Freire  0002094657                         MUTIRAO
# 117            Vitorino Freire  0002094665         OLHO D AGUA MANOEL LUIS
# 118            Vitorino Freire  0002231484             ESF OZEAS CASTRO II
#
# linha_cuidado  citopatologico  cronicos
# 0                          58       112
# 1                          56       197
# 2                          20        47
# 3                         130       212
# 4                          24        55
# ..                        ...       ...
# 114                        45        58
# 115                       246       267
# 116                        96        54
# 117                        45        54
# 118                        62        42
#
# [115 rows x 5 columns]

# %% [markdown]
# #### Randomização e divisão dos grupos

# %%
# randomização os grupos de teste e controle por equipes
controle, teste = train_test_split(df_equipes, test_size=0.5, random_state=42,stratify=df_equipes['municipio'])

controle['grupo'] = 'controle'
teste['grupo'] = 'teste'
df_equipes = pd.concat([controle, teste])
df_equipes
# Out:
# linha_cuidado        municipio  equipe_ine                equipe_nome  \
# 26              Brejo de Areia  0001925806          EQUIPE BREJO NOVO
# 82                 Paulo Ramos  0000054755        ESF VILA RAPINA - I
# 104            Vitorino Freire  0000064246                 ESF JACARE
# 7                      Baraúna  0000107263                     ESF VI
# 13                     Baraúna  0000107344                      ESF X
# ..                         ...         ...                        ...
# 118            Vitorino Freire  0002231484        ESF OZEAS CASTRO II
# 116            Vitorino Freire  0002094657                    MUTIRAO
# 99                    Tarrafas  0000104825                 EQUIPE III
# 85                 Paulo Ramos  0002214261  ESF CENTRO DOS LEITE - II
# 59                    Oiapoque  0000035092                   PLANALTO
#
# linha_cuidado  citopatologico  cronicos     grupo
# 26                        103        71  controle
# 82                        126       149  controle
# 104                       122        81  controle
# 7                          41        46  controle
# 13                         23        41  controle
# ..                        ...       ...       ...
# 118                        62        42     teste
# 116                        96        54     teste
# 99                        419       645     teste
# 85                         32        30     teste
# 59                        101       192     teste
#
# [115 rows x 6 columns]

# %%
df_grupos = df_aptos_mensagens.merge(df_equipes[['equipe_ine','grupo']], how='left',on='equipe_ine')

# %%
df_grupos.drop_duplicates(inplace=True)
df_grupos = df_grupos[df_grupos['equipe_ine']!='0']

# %% [markdown]
# #### Salvando os dados de divisão de grupos numa tabela do BQ para seleção diária

# %%
df_grupos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23240 entries, 0 to 23270
# Data columns (total 39 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   municipio                                         23240 non-null  object
#  1   nome_do_paciente                                  23240 non-null  object
#  2   celular_tratado                                   23200 non-null  Int64
#  3   cns                                               14469 non-null  Int64
#  4   cpf                                               23240 non-null  Int64
#  5   data_de_nascimento                                23240 non-null  dbdate
#  6   ds_dim_situacao_trabalho                          23240 non-null  object
#  7   ds_identidade_genero                              23240 non-null  object
#  8   no_social_cidadao                                 1909 non-null   object
#  9   numero_visitas_ubs_ultimos_12_meses               23240 non-null  Int64
#  10  st_plano_saude_privado                            23240 non-null  Int64
#  11  st_comunidade_tradicional                         23240 non-null  Int64
#  12  se_faleceu                                        23240 non-null  Int64
#  13  se_mudou                                          23240 non-null  Int64
#  14  equipe_ine                                        23240 non-null  object
#  15  equipe_nome                                       23240 non-null  object
#  16  acs_nome_cadastro                                 23240 non-null  object
#  17  esta_na_lista_citopatologico                      23240 non-null  boolean
#  18  data_exame_cito                                   2530 non-null   dbdate
#  19  status_exame                                      13057 non-null  object
#  20  esta_na_lista_hipertensos                         23240 non-null  boolean
#  21  data_afericao_hipertensos                         12441 non-null  dbdate
#  22  possui_hipertensao_autorreferida                  23240 non-null  boolean
#  23  possui_hipertensao_diagnosticada                  23240 non-null  boolean
#  24  realizou_afericao_ultimos_6_meses                 23240 non-null  boolean
#  25  realizou_consulta_hip_ultimos_6_meses             23240 non-null  boolean
#  26  esta_na_lista_diabeticos                          23240 non-null  boolean
#  27  data_exame_diabeticos                             4519 non-null   dbdate
#  28  possui_diabetes_autorreferida                     23240 non-null  boolean
#  29  possui_diabetes_diagnosticada                     23240 non-null  boolean
#  30  realizou_consulta_dia_ultimos_6_meses             23240 non-null  boolean
#  31  realizou_solicitacao_hemoglobina_ultimos_6_meses  23240 non-null  boolean
#  32  mensagem_data_envio                               23240 non-null  object
#  33  citopatologico_pendente                           23240 non-null  bool
#  34  hipertensao_pendente                              23240 non-null  bool
#  35  diabetes_pendente                                 23240 non-null  bool
#  36  cronicos_pendente                                 23240 non-null  bool
#  37  linha_cuidado                                     23240 non-null  object
#  38  grupo                                             23240 non-null  object
# dtypes: Int64(8), bool(4), boolean(11), dbdate(4), object(12)
# memory usage: 5.2+ MB

# %%
# criação da tabela para guardar a análise inicial dos cidadãos
table_id = "predictive-keep-314223.ip_mensageria_camada_prata.divisao_teste_controle_equipes"
job = client.load_table_from_dataframe(df_grupos, table_id)
job.result()
# Out:
# LoadJob<project=predictive-keep-314223, location=US, id=27141d6f-2e5a-4fa8-a1ca-d1a1eb7d47ba>

# %% [markdown]
# #### Verificação de preenchimento de novos campos

# %%
df_dividido.ds_dim_situacao_trabalho.value_counts()
# Out:
# ds_dim_situacao_trabalho
# Não informado                           7158
# Aposentado / Pensionista                6088
# Outro                                   3389
# Não trabalha                            1878
# Desempregado                            1513
# Autônomo sem previdência social         1017
# Assalariado com carteira de trabalho     667
# Assalariado sem carteira de trabalho     626
# Servidor público / Militar               508
# Autônomo com previdência social          303
# Empregador                                93
# Name: count, dtype: int64

# %%
df_dividido.st_plano_saude_privado.value_counts()
# Out:
# st_plano_saude_privado
# 0    23047
# 1      193
# Name: count, dtype: Int64

# %%
df_dividido.st_comunidade_tradicional.value_counts()
# Out:
# st_comunidade_tradicional
# 0    22720
# 1      520
# Name: count, dtype: Int64

# %%
df_dividido.ds_identidade_genero.value_counts()
# Out:
# ds_identidade_genero
# Não informado         22838
# Mulher cisgênero        174
# Outro                    86
# Homem cisgênero          64
# Homem transgênero        46
# Mulher transgênero       31
# Transgênero               1
# Name: count, dtype: int64

# %% [markdown]
# #### Criação da estrutura da tabela para guardar o histórico de envios

# %%
df_historico_envios = pd.DataFrame(columns=['municipio', 'equipe_ine', 'equipe_nome', 'linha_cuidado','nome_do_paciente','data_de_nascimento','celular_tratado','horario_grupo','data_envio'])
df_historico_envios = df_historico_envios.astype({'data_de_nascimento': 'datetime64[ns]', 'data_envio': 'datetime64[ns]'})
df_historico_envios
# Out:
# Empty DataFrame
# Columns: [municipio, equipe_ine, equipe_nome, linha_cuidado, nome_do_paciente, data_de_nascimento, celular_tratado, horario_grupo, data_envio]
# Index: []

# %%
# criação da tabela para guardar o histórico de envios
table_id = "predictive-keep-314223.ip_mensageria_camada_prata.historico_envio_mensagens"
job = client.load_table_from_dataframe(df_historico_envios, table_id)
job.result()
# Out:
# LoadJob<project=predictive-keep-314223, location=US, id=6f139ccb-4206-4631-9d4d-1791df047422>
